# %%
import os 
from os import listdir

# %%
# def rename(path): #NE POKRECIIIIIIIIIII
#     for filename in listdir(path):
#         if len(filename.split(".mid"))>1:
#             new_name = filename.split(".mid")[0] + filename.split(".mid")[1]
#             os.rename("C:/soft/bb/MusicGenerator/data5/" +filename, new_name)
# rename("C:/soft/bb/MusicGenerator/data5")

# %%
def make_dictionary_first_notes(path):
    dictionary = {}
    num=0;
    for filename in listdir(path):
        #print(filename)
        if num >9200:
            break
        file = open("C:/soft/bb/MusicGenerator/data5/"+filename, 'r') 
        text = file.read() 
        file.close()
        file2 = open("C:/soft/bb/MusicGenerator/first_notes.txt", 'a')   
        first_notes = text.split(" ")[0:5]
        line = filename.split(".txt")[0] + " " +first_notes[0] + " " +first_notes[1] + " " +first_notes[2] + " " +first_notes[3] + " " +first_notes[4] +  "\n"
        file2.writelines(line)
        file2.close()
        file.close()
        num += 1
        dictionary[filename] = first_notes
    return dictionary

# %%
print(make_dictionary_first_notes("C:/soft/bb/MusicGenerator/data5"))
# Out:
# {'Day Of The TentacleDayOfTheTentacle-HumanShow.txt': ['0-0-74-100-45', '0-0-71-100-45', '0-1-59-100-56', '0-1-62-100-56', '0-2-59-100-71'], 'Day Of The TentacleDayOfTheTentacle-OpeningStart.txt': ['0-0-72-100-72', '0-1-55-100-46', '0-4-72-100-45', '0-4-60-100-45', '105-1-60-100-46'], 'Day Of The TentacleDayOfTheTentacle-Theme.txt': ['0-0-64-127-63', '0-0-64-127-63', '0-3-46-100-34', '0-8-64-40-56', '0-8-64-40-56'], 'Daytona USADaytona_USA_-_The_King_of_Speed.txt': ['0-10-76-80-85', '0-11-64-80-85', '635-10-76-0-85', '635-10-71-80-85', '635-11-64-0-85'], "Daytona USALet's_Go_Away-Intermediate_Track.txt": ['192-0-64-115-65', '204-0-64-0-65', '216-0-62-115-65', '228-0-62-0-65', '228-0-64-115-65'], 'Dead or Alive 2T_DeadorAlive2_Kasumi.txt': ['0-2-33-94-33', '0-3-33-86-34', '0-4-62-78-48', '0-4-57-78-48', '0-4-69-78-48'], 'Dead or Alive 2T_DeadorAlive2_Kasumi_XG.txt': ['0-2-33-94-33', '0-3-33-86-36', '0-4-64-78-48', '0-4-86-78-48', '0-4-81-78-48'], 'Deadly Rooms of DeathDROD-AWE.txt': [
# ...
